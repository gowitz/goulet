# %% [markdown]
# # Impot libraries #

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# # Define files to read #

# %% [markdown]
# ## Parcelles ##

# %%
file_NPCS = "../data/NPCS_CAD_TPR_PARV_S.shp"
file_MOVD = "../data/MOVD_CAD_TPR_PARV_S.shp"

# %% [markdown]
# ## Base map ##

# %%
file_lakes = "../data/MN95_OIT_TPR_LAD_GEN_LAC.shp"
file_highways = "../data/autoroutes.shp"
file_communes_geom = '../data/MN95_CAD_TPR_LAD_COM_S.shp'

# %% [markdown]
# ## Other data ##

# %%
file_communes = '../data/communes_vd.csv'

# %% [markdown]
# # Load parcelles data #

# %%
parcelles_NPCS = gpd.read_file(file_NPCS)
parcelles_MOVD = gpd.read_file(file_MOVD)

# %% [markdown]
# ## Merge parcelles dataframe ##

# %%
parcelles = pd.concat([parcelles_NPCS, parcelles_MOVD])
# Out:
# 59467

# %% [markdown]
# ## Add column for  'no_com_can' ##

# %%
# new column 'no_com_can' based from 'IDENTDN' remove extra char
parcelles['no_com_can'] = parcelles['IDENTDN'].str[3:6].str.lstrip('0')

# %% [markdown]
# ### check data ###

# %%
len(parcelles)
# Out:
# 59467

# %%
parcelles.head()
# Out:
#     NUMERO   IDEX2000 VALIDITE_T  VALIDITE      EGRIS_EGRI       ID  \
# 0      395  188000395        oui         0  CH875779973676  4667951
# 1      391  188000391        oui         0  CH155083924553  4667892
# 2  DP 1082  188101082        oui         0  CH733679579889  4668475
# 3      390  188000390        oui         0  CH915797367921  4667965
# 4      385  188000385        oui         0  CH815798367946  4668483
#
#     SHAPE_LEN INTEGRALIT       IDENTDN SUPERFICIE    SHAPE_AREA  \
# 0  331.053892    complet  VD0188000000       None   5416.416482
# 1  708.502347    complet  VD0188000000       None  28477.592318
# 2  120.546197    complet  VD0188000000       None    252.620991
# 3  224.991879    complet  VD0188000000       None   2388.017807
# 4  342.345214    complet  VD0188000000       None   6160.181288
#
#          GENRE_TXT  GENRE                                           geometry  \
# 0  parcelle privée      0  POLYGON ((2520785.144 1152586.504, 2520799.374...
# 1  parcelle privée      0  POLYGON ((2520834.171 1152876.256, 2520876.733...
# 2      DP communal      1  POLYGON ((2520997.048 1152956.177, 2521002.725...
# 3  parcelle privée      0  POLYGON ((2521061.380 1152783.924, 2521023.014...
# 4  parcelle privée      0  POLYGON ((2521232.489 1152583.232, 2521226.654...
#
#   no_com_can
# 0        188
# 1        188
# 2        188
# 3        188
# 4        188

# %%
parcelles.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Load commune data #

# %%
communes_data = pd.read_csv(file_communes)
# cleanup
communes_data = communes_data.drop(['GEOMETRY'], axis=1)

# %% [markdown]
# ### Check data ##

# %%
communes_data.head()
# Out:
#    ogc_fid  no_com_can  no_com_fed                nom_min  \
# 0        1         102        5535  Saint-Barthélemy (VD)
# 1        2         336        5861                  Rolle
# 2        3         381        5932                 Ursins
# 3        4         258        5745                Baulmes
# 4        5         289        5790                Maracon
#
#                  nom_maj  no_dis_can  no_dis_fed  no_canton  perimetre
# 0  SAINT-BARTHÉLEMY (VD)           3        2223         22        NaN
# 1                  ROLLE           8        2228         22        NaN
# 2                 URSINS           4        2224         22        NaN
# 3                BAULMES           4        2224         22        NaN
# 4                MARACON           6        2226         22        NaN

# %% [markdown]
# # Create geodataframe #

# %% [markdown]
# ## Get geometries ##

# %%
communes_geom = gpd.read_file(file_communes_geom)
communes_geom = communes_geom.rename(str.lower, axis='columns')
communes_geom = communes_geom[['no_com_can', 'geometry']]

# %%
communes_geom.head()
# Out:
#    no_com_can                                           geometry
# 0         102  POLYGON ((2536799.038 1166156.651, 2536797.628...
# 1         336  POLYGON ((2513913.773 1144416.026, 2513999.465...
# 2         381  POLYGON ((2541753.782 1177514.664, 2541835.857...
# 3         258  POLYGON ((2524665.641 1180812.700, 2524648.391...
# 4         289  POLYGON ((2556252.645 1154636.452, 2556250.824...

# %% [markdown]
# ## Create final geodataframe ##

# %%
communes = gpd.GeoDataFrame()
communes['geometry'] = None

# %% [markdown]
# ### Merge communes and communes_data ###

# %%
communes = communes.append(communes_data)
#communes = communes.drop(['geometry'], axis=1)

# %% [markdown]
# ### Merge communes and geometries ###

# %%
communes = communes.merge(communes_geom, on='no_com_can')

# %% [markdown]
# ### check data ###

# %%
communes.head()
# Out:
#    ogc_fid  no_com_can  no_com_fed                nom_min  \
# 0      1.0       102.0      5535.0  Saint-Barthélemy (VD)
# 1      2.0       336.0      5861.0                  Rolle
# 2      3.0       381.0      5932.0                 Ursins
# 3      4.0       258.0      5745.0                Baulmes
# 4      5.0       289.0      5790.0                Maracon
#
#                  nom_maj  no_dis_can  no_dis_fed  no_canton  perimetre  \
# 0  SAINT-BARTHÉLEMY (VD)         3.0      2223.0       22.0        NaN
# 1                  ROLLE         8.0      2228.0       22.0        NaN
# 2                 URSINS         4.0      2224.0       22.0        NaN
# 3                BAULMES         4.0      2224.0       22.0        NaN
# 4                MARACON         6.0      2226.0       22.0        NaN
#
#                                             geometry
# 0  POLYGON ((2536799.038 1166156.651, 2536797.628...
# 1  POLYGON ((2513913.773 1144416.026, 2513999.465...
# 2  POLYGON ((2541753.782 1177514.664, 2541835.857...
# 3  POLYGON ((2524665.641 1180812.700, 2524648.391...
# 4  POLYGON ((2556252.645 1154636.452, 2556250.824...

# %% [markdown]
# # Plot all #

# %% [markdown]
# ## Extract data for layers ##

# %%
perim1 = communes.loc[communes['perimetre']==1]
perim2 = communes.loc[communes['perimetre']==2]
lakes = gpd.read_file(file_lakes)
highways = gpd.read_file(file_highways)

# %%
fig, ax = plt.subplots(figsize=(10,10))
communes.plot(ax=ax, facecolor='silver', edgecolor='darkgrey')
perim1.plot(ax=ax, facecolor='lightgreen', edgecolor='green')
perim2.plot(ax=ax, facecolor='gold', edgecolor='goldenrod')
lacs.plot(ax=ax, facecolor='lightblue', edgecolor='steelblue')
autoroutes.plot(ax=ax, facecolor='none', edgecolor='dimgrey')
# Out:
# <AxesSubplot:>
